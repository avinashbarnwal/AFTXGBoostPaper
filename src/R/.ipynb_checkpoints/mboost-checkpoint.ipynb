# %%
library(mboost)
library(survival)
library(penaltyLearning)
library(Hmisc)
library(caret)

# %%
data_import =function(dataname){
  filename = paste('https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/',dataname,'/',sep="")
  inputFileName = paste(filename,'inputs.csv',sep="")
  labelFileName = paste(filename,'outputs.csv',sep="")
  foldsFileName = paste(filename,'cv/equal_labels/folds.csv',sep="")
  inputs        = read.table(inputFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
  labels        = read.table(labelFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
  folds         = read.table(foldsFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
  res           = list()
  res$inputs    = inputs
  res$labels    = labels
  res$folds     = folds
  return(res)
}

# %%
data_massage = function(inputs,labels){
    rownamesInput = rownames(inputs)
    inputs        = do.call(data.frame,lapply(inputs, function(x) replace(x, is.infinite(x),NA)))
    naColumns     = colnames(inputs)[colSums(is.na(inputs))>0]
    noVarCol      = getNonVarCols(inputs)
    removeCols    = c(naColumns,noVarCol)
    inputs        = inputs[ , !(colnames(inputs) %in% removeCols)]
    rownames(inputs) = rownamesInput
    labels$min.log.lambda = unlist(lapply(labels$min.log.lambda,exp))
    labels$max.log.lambda = unlist(lapply(labels$max.log.lambda,exp))
    res        = list()
    res$inputs = inputs
    res$labels = labels
    return(res)
}

# %%
getXY<-function(foldNo,folds,inputs,labels){
    test.id       = rownames(subset(folds,fold==foldNo))
    train.id      = rownames(subset(folds,fold!=foldNo))
    X             = subset(inputs,rownames(inputs) %in% train.id)
    X             = as.matrix(X)
    X.val         = subset(inputs,rownames(inputs) %in% test.id)
    X.val         = as.matrix(X.val)
    y.label       = subset(labels,rownames(labels) %in% train.id)
    y.label.test  = subset(labels,rownames(labels) %in% test.id)
    y.lower       = as.matrix(y.label$min.log.lambda)
    y.upper       = as.matrix(y.label$max.log.lambda)
    y.lower.val   = as.matrix(y.label.test$min.log.lambda)
    y.upper.val   = as.matrix(y.label.test$max.log.lambda)
    res           = list()
    res$X         = X
    res$X.val     = X.val
    res$y.lower      = y.lower
    res$y.lower.val  = y.lower.val
    res$y.upper      = y.upper
    res$y.upper.val  = y.upper.val
    return(res)
}

# %%
getNonVarCols<-function(data){
    var_columns    = apply(inputs,2,var)
    resCol         = names(var_columns[var_columns==0.0])
    return(resCol)
}

# %%
# Set Parameters
dataNameRange       = c('ATAC_JV_adipose','CTCF_TDH_ENCODE','H3K27ac-H3K4me3_TDHAM_BP','H3K27ac_TDH_some','H3K36me3_AM_immune')
sigma_range         = c(1,2,5,10,100)
distribution_range  = c('normal','logistic','extreme')
learning_rate       = 0.1
num_round           = 200

# %%
res                 = data_import(dataNameRange[1])
inputs              = res$inputs
labels              = res$labels
folds               = res$folds
resDataMassage      = data_massage(inputs,labels)
inputs              = resDataMassage$inputs
labels              = resDataMassage$labels
fold_iter           = unique(folds$fold)
accuracy_fold       = numeric(length(fold_iter))
coef_model          = list()

# %%
getaccuracy=function(pred,y_lower,y_higher){
    res = (pred>=y_lower & pred<=y_higher)
    return(res)
}

# %%
for(i in 1:length(fold_iter)){
    res                 = getXY(fold_iter[i],folds,inputs,labels)
    X                   = res$X
    X.val               = res$X.val
    y.lower             = res$y.lower
    y.lower.val         = res$y.lower.val
    y.upper             = res$y.upper
    y.upper.val         = res$y.upper.val
    train.folds         = cut(seq(1,nrow(X)),breaks=5,labels=FALSE)
    res                 = list()
    my.surv             = Surv(y.lower,y.upper,type='interval2')
    formula             = as.formula(paste("my.surv ~", paste(colnames(X),collapse="+")))
    trn.data            = data.frame(X,y.lower,y.upper)
    glm = glmboost(formula,data=trn.data,family=Lognormal(),control=boost_control(mstop=200,nu=0.005))
    coef_model[i]       = coef(glm)
    tst.data            = data.frame(X.val)
    pred.y.val          = predict(glm,tst.data)
    print(y.lower.val)
    print(y.upper.val)
    accuracy_fold[i]    = sum(mapply(getaccuracy,pred.y.val,y.lower.val,y.upper.val))/length(pred.y.val)
}
# Out:
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(risk, interval = c(0, max(log(y[, 1]), na.rm = TRUE)), :
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# ...
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in optimize(riskS, interval = nuirange, y = y, fit = f, w = w):
# “NA/Inf replaced by maximum positive value”
# Warning message in coef_model[i] <- coef(glm):
# “number of items to replace is not a multiple of replacement length”
#              [,1]
#  [1,]   1851.6243
#  [2,]   5815.0514
#  [3,]   1728.2432
#  [4,]   4362.1733
#  [5,]   1972.7023
#  [6,]   7027.6479
#  [7,]   1143.4934
#  [8,]   5753.4128
#  [9,]   4627.2812
# [10,]    853.5970
# [11,]   2254.1107
# [12,]   3911.8460
# [13,]   1414.6254
# [14,]   4114.3944
# [15,]   3047.1845
# [16,] 674129.7398
# [17,]  14303.4850
# [18,]   5398.4726
# [19,]   2632.7089
# [20,]   3567.9991
# [21,]   5396.7533
# [22,]   1397.9884
# [23,]  10995.5308
# [24,]   4873.7242
# [25,]   1875.1230
# [26,]   7245.4484
# [27,]   4092.7882
# [28,]   1424.7450
# [29,]   6713.3998
# [30,]   5992.0096
# [31,]   2606.2170
# [32,]   5064.8658
# [33,]   2506.0091
# [34,]   4939.6687
# [35,]   3985.4505
# [36,]   6761.5041
# [37,]   1882.8807
# [38,]   3744.1338
# [39,]    549.1429
# [40,]   4757.0784
# [41,]    678.4340
# [42,]   1109.1693
# [43,]    720.7120
# [44,]   3140.8973
# [45,]    778.1472
# [46,]   4397.9517
# [47,]    833.8130
# [48,]   4066.7932
# [49,]   1660.9558
# [50,]    575.3980
# [51,]   3483.4540
# [52,]   2074.8837
# [53,]    967.0517
# [54,]  15109.8388
# [55,]   5892.4528
# [56,]    820.5162
# [57,]    907.8378
# [58,]   3487.4688
# [59,]    931.1004
# [60,]   6778.0708
# [61,]   5805.0647
# [62,]   1152.6818
# [63,]   1793.5974
# [64,]   5582.4248
# [65,]   1078.8688
# [66,]   4080.0865
# [67,]   3240.3296
# [68,]   1032.5659
# [69,]   6175.0402
# [70,]   1028.0809
# [71,]   3746.4845
# [72,]   1012.9560
# [73,]   3340.5629
# [74,]    706.0551
# [75,]   4418.5680
# [76,]   1083.3674
# [77,]   1261.7512
# [78,]   2829.6751
# [79,]   2468.0710
# [80,]   9308.5691
# [81,]   3179.5078
# [82,]   1339.3884
# [83,]  21699.9294
# [84,]   4290.6654
# [85,]   2153.6531
# [86,]   4345.5946
# [87,]   2662.9842
#             [,1]
#  [1,] 14457.5909
#  [2,] 25625.9280
#  [3,] 16316.0301
#  [4,] 35488.0023
#  [5,] 22439.2515
#  [6,] 33617.7008
#  [7,]  6478.2358
#  [8,]  9314.4891
#  [9,] 11351.6629
# [10,]  4596.4584
# [11,]  6128.0898
# [12,] 13267.7927
# [13,]  8072.3575
# [14,]  5025.9399
# [15,] 11860.9765
# [16,]        Inf
# [17,] 27152.4399
# [18,]  6530.5293
# [19,]  4655.7413
# [20,] 13043.4502
# [21,]  9430.5978
# [22,] 17034.1071
# [23,] 24100.5607
# [24,] 27138.7491
# [25,]  5497.2510
# [26,] 16561.7036
# [27,] 12685.0941
# [28,] 21500.7774
# [29,] 32288.2997
# [30,] 30860.2602
# [31,] 15733.8102
# [32,] 37614.7139
# [33,] 14984.4854
# [34,] 48511.6922
# [35,] 24376.6747
# [36,] 50977.3839
# [37,]  3150.5360
# [38,] 20742.6675
# [39,]  1002.0127
# [40,] 24045.9819
# [41,]  4199.2924
# [42,]  4995.9660
# [43,]  5861.8572
# [44,] 26039.8007
# [45,] 19891.0235
# [46,] 17006.5108
# [47,]  1093.3310
# [48,]  9763.3478
# [49,]  9440.0596
# [50,]  1691.4740
# [51,]  5242.9323
# [52,] 26072.9102
# [53,]  1255.1385
# [54,] 20489.7635
# [55,]  7848.4593
# [56,]  1515.1627
# [57,]  1998.5117
# [58,] 14891.2471
# [59,] 17349.7740
# [60,] 30384.4961
# [61,] 29104.8962
# [62,]  2435.4095
# [63,]  2019.7162
# [64,] 25378.1488
# [65,]  7574.9501
# [66,]  4587.9663
# [67,] 13511.3723
# [68,]  1043.1947
# [69,] 31223.1303
# [70,]  6197.9311
# [71,]  5173.8754
# [72,]  1740.0912
# [73,] 10968.7809
# [74,]   895.0979
# [75,]  8232.2184
# [76,]  9619.9877
# [77,] 12014.7857
# [78,] 21103.8805
# [79,] 12583.5895
# [80,] 15008.8651
# [81,] 34623.0636
# [82,] 16266.5310
# [83,] 23630.3512
# [84,] 59395.5017
# [85,]  8223.1659
# [86,] 11528.0689
# [87,] 15386.7845

# %%
pred.y.val
# Out:
#                                                                     [,1]
# ATAC_JV_adipose/samples/AC1/MSC77/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC1/MSC77/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC1/MSC80/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC1/MSC83/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC1/MSC91/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC1/MSC91/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC70/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC70/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC70/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC72/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC72/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC72/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC73/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC73/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC73/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC74/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC74/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC74/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC77/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC77/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC77/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC80/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC80/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC80/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC83/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC83/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC83/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AC2/MSC91/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AC2/MSC91/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AC2/MSC91/problems/chr3:60000-66170270      -245.2289
# ⋮                                                                   ⋮
# ATAC_JV_adipose/samples/AD2/MSC74/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AD2/MSC80/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AD2/MSC80/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AD2/MSC80/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AD2/MSC83/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AD2/MSC83/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AD2/MSC83/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/AD2/MSC91/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/AD2/MSC91/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/AD2/MSC91/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/Ai/MSC77/problems/chr1:206482221-223747846  -245.2289
# ATAC_JV_adipose/samples/Ai/MSC77/problems/chr3:60000-66170270       -245.2289
# ATAC_JV_adipose/samples/Ai/MSC80/problems/chr1:206482221-223747846  -245.2289
# ATAC_JV_adipose/samples/Ai/MSC80/problems/chr3:60000-66170270       -245.2289
# ATAC_JV_adipose/samples/Ai/MSC83/problems/chr1:206482221-223747846  -245.2289
# ATAC_JV_adipose/samples/Ai/MSC83/problems/chr3:60000-66170270       -245.2289
# ATAC_JV_adipose/samples/Ai/MSC91/problems/chr1:206482221-223747846  -245.2289
# ATAC_JV_adipose/samples/Ai/MSC91/problems/chr3:60000-66170270       -245.2289
# ATAC_JV_adipose/samples/ND2/MSC77/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/ND2/MSC77/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/ND2/MSC77/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/ND2/MSC80/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/ND2/MSC80/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/ND2/MSC80/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/ND2/MSC83/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/ND2/MSC83/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/ND2/MSC83/problems/chr3:60000-66170270      -245.2289
# ATAC_JV_adipose/samples/ND2/MSC91/problems/chr1:206482221-223747846 -245.2289
# ATAC_JV_adipose/samples/ND2/MSC91/problems/chr22:20700000-50364777  -245.2289
# ATAC_JV_adipose/samples/ND2/MSC91/problems/chr3:60000-66170270      -245.2289
