# %%
import xgboost as xgb
import pandas  as pd
import numpy   as np
from   sklearn.model_selection import KFold
import optuna
import time
import json

# %%
def data_import(data_name):
    filename = 'https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/'+data_name+'/'
    inputFileName = filename+'inputs.csv'
    labelFileName = filename+'outputs.csv'
    foldsFileName = filename+'cv/equal_labels/folds.csv'
    inputs        = pd.read_csv(inputFileName,index_col='sequenceID')
    labels        = pd.read_csv(labelFileName,index_col='sequenceID')
    folds         = pd.read_csv(foldsFileName,index_col='sequenceID')
    res           = {}
    res['inputs'] = inputs
    res['labels'] = labels
    res['folds']  = folds
    return(res)

# %%
def data_massage(inputs,labels):
    inputs.replace([-float('inf'),float('inf')],np.nan,inplace=True)
    missingCols = inputs.isnull().sum()
    missingCols = list(missingCols[missingCols>0].index)
    inputs.drop(missingCols,axis=1,inplace=True)
    varCols     = inputs.apply(lambda x: np.var(x))
    zeroVarCols = list(varCols[varCols==0].index)
    inputs.drop(zeroVarCols,axis=1,inplace=True)
    labels['min.log.lambda'] = labels['min.log.lambda'].apply(lambda x: np.exp(x))
    labels['max.log.lambda'] = labels['max.log.lambda'].apply(lambda x: np.exp(x))
    return inputs,labels

# %%
def getXY(foldNo,folds,inputs,labels):
    test_id       = list(folds[folds['fold']==foldNo].index)
    train_id      = list(folds[folds['fold']!=foldNo].index)
    X             = inputs[inputs.index.isin(train_id)]
    X_val         = inputs[inputs.index.isin(test_id)]
    y_label       = labels[labels.index.isin(train_id)]
    y_label_test  = labels[labels.index.isin(test_id)]
    y_lower       = y_label['min.log.lambda']
    y_upper       = y_label['max.log.lambda']
    y_lower_val   = y_label_test['min.log.lambda']
    y_upper_val   = y_label_test['max.log.lambda']
    res           = {}
    res['X']         = X
    res['X_val']     = X_val
    res['y_lower']      = y_lower
    res['y_lower_val']  = y_lower_val
    res['y_upper']      = y_upper
    res['y_upper_val']  = y_upper_val
    return res

# %%
def trainModel(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower.values)
    dtrain.set_float_info("label_upper_bound",y_upper.values)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val.values)
    dtest.set_float_info("label_upper_bound",y_upper_val.values)
    
    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    min_val_error = round(np.min(res['test'][distributionCol]),4)
    return(min_val_error)

# %%
def objective(trial):
    SEED         = 1
    Kfolds       = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 10000
    res          = 0
    # Discrete-uniform parameter
    eta              = trial.suggest_discrete_uniform('eta',0.001,1.001,0.1)
    max_depth        = trial.suggest_discrete_uniform('max_depth',2, 10,2)
    min_child_weight = trial.suggest_discrete_uniform('min_child_weight',0.1,100.1,10)
    reg_alpha        = trial.suggest_loguniform('reg_alpha',0.0001,100)
    reg_lambda       = trial.suggest_loguniform('reg_lambda',0.0001,100)
    sigma            = trial.suggest_discrete_uniform('sigma',1,100,1)
    distribution     = trial.suggest_categorical('distribution',['normal','logistic','extreme'])
    
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res = res + trainModel(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    return res

# %%
def best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution): 
    SEED         = 1
    Kfolds        = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 10000
    # Discrete-uniform parameter
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    res_data = pd.DataFrame()
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res_data[fold_] = trainModelIter(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    res_data['total'] = res_data.sum(axis=1)
    num_round = res_data.idxmin(axis=0, skipna=True)['total']
    return num_round

# %%
data_name_domain = ['ATAC_JV_adipose','CTCF_TDH_ENCODE','H3K27ac-H3K4me3_TDHAM_BP','H3K27ac_TDH_some','H3K36me3_AM_immune']

# %%
data      = data_import(data_name_domain[3])
data_name = data_name_domain[3]

# %%
inputs = data['inputs']
labels = data['labels']
folds  = data['folds']

# %%
inputs,labels = data_massage(inputs,labels)

# %%
global X
global X_val
global y_lower
global y_upper
global y_upper_val

# %%
for fold in np.unique(folds['fold'].values):
    res          = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    study        = optuna.create_study()
    start        = time.time()
    study.optimize(objective, n_trials=100)
    trial         = study.best_trial
    json_filename = "../../../../result/"+data_name+"/xgboost/fold"+str(fold)+'_param.json'
    with open(json_filename, "w") as write_file:
        json.dump(trial.params, write_file)
# Out:
# [I 2019-12-08 08:23:57,142] Finished trial#0 resulted in value: 19.0272. Current best value is 19.0272 with parameters: {'eta': 0.101, 'max_depth': 4.0, 'min_child_weight': 100.1, 'reg_alpha': 0.0011087824836271013, 'reg_lambda': 0.021256663375509757, 'sigma': 62.0, 'distribution': 'normal'}.
# [I 2019-12-08 08:24:02,448] Finished trial#1 resulted in value: 20.9025. Current best value is 19.0272 with parameters: {'eta': 0.101, 'max_depth': 4.0, 'min_child_weight': 100.1, 'reg_alpha': 0.0011087824836271013, 'reg_lambda': 0.021256663375509757, 'sigma': 62.0, 'distribution': 'normal'}.
# [I 2019-12-08 08:24:08,638] Finished trial#2 resulted in value: 21.4411. Current best value is 19.0272 with parameters: {'eta': 0.101, 'max_depth': 4.0, 'min_child_weight': 100.1, 'reg_alpha': 0.0011087824836271013, 'reg_lambda': 0.021256663375509757, 'sigma': 62.0, 'distribution': 'normal'}.
# [I 2019-12-08 08:24:14,820] Finished trial#3 resulted in value: 20.4307. Current best value is 19.0272 with parameters: {'eta': 0.101, 'max_depth': 4.0, 'min_child_weight': 100.1, 'reg_alpha': 0.0011087824836271013, 'reg_lambda': 0.021256663375509757, 'sigma': 62.0, 'distribution': 'normal'}.
# [I 2019-12-08 08:24:20,417] Finished trial#4 resulted in value: 10.6157. Current best value is 10.6157 with parameters: {'eta': 0.6010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.0007542279571254234, 'reg_lambda': 1.369158997263217, 'sigma': 4.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:24:25,713] Finished trial#5 resulted in value: 15.6563. Current best value is 10.6157 with parameters: {'eta': 0.6010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.0007542279571254234, 'reg_lambda': 1.369158997263217, 'sigma': 4.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:24:31,003] Finished trial#6 resulted in value: 18.9857. Current best value is 10.6157 with parameters: {'eta': 0.6010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.0007542279571254234, 'reg_lambda': 1.369158997263217, 'sigma': 4.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:24:37,204] Finished trial#7 resulted in value: 11.584200000000001. Current best value is 10.6157 with parameters: {'eta': 0.6010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.
Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:02,456] Finished trial#80 resulted in value: 13.902899999999999. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:08,127] Finished trial#81 resulted in value: 8.4228. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:13,806] Finished trial#82 resulted in value: 8.422699999999999. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:19,483] Finished trial#83 resulted in value: 15.1687. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:25,160] Finished trial#84 resulted in value: 11.648700000000002. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:30,837] Finished trial#85 resulted in value: 14.745700000000001. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:36,517] Finished trial#86 resulted in value: 8.4953. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:42,196] Finished trial#87 resulted in value: 17.0603. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:47,871] Finished trial#88 resulted in value: 11.641300000000001. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:53,556] Finished trial#89 resulted in value: 14.7476. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 08:59:59,242] Finished trial#90 resulted in value: 8.442. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:04,963] Finished trial#91 resulted in value: 8.4213. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:10,647] Finished trial#92 resulted in value: 14.748899999999999. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:16,332] Finished trial#93 resulted in value: 8.4223. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:22,022] Finished trial#94 resulted in value: 8.4209. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:27,707] Finished trial#95 resulted in value: 11.6539. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:33,391] Finished trial#96 resulted in value: 14.284899999999999. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:39,074] Finished trial#97 resulted in value: 11.6581. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:44,782] Finished trial#98 resulted in value: 16.5178. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:00:50,481] Finished trial#99 resulted in value: 10.6234. Current best value is 8.414499999999999 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.0018144485946196241, 'reg_lambda': 13.775666916098642, 'sigma': 1.0, 'distribution': 'logistic'}.

# %%
def trainModelIter(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_upper)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_upper_val)

    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    val_error = res['test'][distributionCol]
    
    return(val_error)

# %%
#for fold in range(2,3):
for fold in np.unique(folds['fold'].values):
    res = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    json_filename = "../../../../result/"+data_name+"/xgboost/"+"fold"+str(fold)+'_param.json'
    with open(json_filename, errors='ignore') as json_data:
        json_fold = json.load(json_data, strict=False)
    eta = json_fold['eta']
    max_depth = json_fold['max_depth']
    min_child_weight = json_fold['min_child_weight']
    reg_alpha = json_fold['reg_alpha']
    reg_lambda = json_fold['reg_lambda']
    sigma= json_fold['sigma']
    distribution = json_fold['distribution'] 
    num_round = best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution)
    new_json = {}
    new_json['eta'] = eta
    new_json['max_depth'] = max_depth
    new_json['min_child_weight'] = min_child_weight
    new_json['reg_alpha'] = reg_alpha
    new_json['reg_lambda'] = reg_lambda
    new_json['sigma'] = sigma
    new_json['distribution'] = distribution
    new_json['num_round'] = int(num_round)
    json_filename = "../../../../result/"+data_name+"/xgboost/fold_new"+str(fold)+'_param.json'
    with open(json_filename, "w") as write_file:
         json.dump(new_json, write_file)
