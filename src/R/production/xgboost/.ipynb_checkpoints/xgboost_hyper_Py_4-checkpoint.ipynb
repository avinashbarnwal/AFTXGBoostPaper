# %%
import xgboost as xgb
import pandas  as pd
import numpy   as np
from   sklearn.model_selection import KFold
import optuna
import time
import json

# %%
def data_import(data_name):
    filename = 'https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/'+data_name+'/'
    inputFileName = filename+'inputs.csv'
    labelFileName = filename+'outputs.csv'
    foldsFileName = filename+'cv/equal_labels/folds.csv'
    inputs        = pd.read_csv(inputFileName,index_col='sequenceID')
    labels        = pd.read_csv(labelFileName,index_col='sequenceID')
    folds         = pd.read_csv(foldsFileName,index_col='sequenceID')
    res           = {}
    res['inputs'] = inputs
    res['labels'] = labels
    res['folds']  = folds
    return(res)

# %%
def data_massage(inputs,labels):
    inputs.replace([-float('inf'),float('inf')],np.nan,inplace=True)
    missingCols = inputs.isnull().sum()
    missingCols = list(missingCols[missingCols>0].index)
    inputs.drop(missingCols,axis=1,inplace=True)
    varCols     = inputs.apply(lambda x: np.var(x))
    zeroVarCols = list(varCols[varCols==0].index)
    inputs.drop(zeroVarCols,axis=1,inplace=True)
    labels['min.log.lambda'] = labels['min.log.lambda'].apply(lambda x: np.exp(x))
    labels['max.log.lambda'] = labels['max.log.lambda'].apply(lambda x: np.exp(x))
    return inputs,labels

# %%
def getXY(foldNo,folds,inputs,labels):
    test_id       = list(folds[folds['fold']==foldNo].index)
    train_id      = list(folds[folds['fold']!=foldNo].index)
    X             = inputs[inputs.index.isin(train_id)]
    X_val         = inputs[inputs.index.isin(test_id)]
    y_label       = labels[labels.index.isin(train_id)]
    y_label_test  = labels[labels.index.isin(test_id)]
    y_lower       = y_label['min.log.lambda']
    y_upper       = y_label['max.log.lambda']
    y_lower_val   = y_label_test['min.log.lambda']
    y_upper_val   = y_label_test['max.log.lambda']
    res           = {}
    res['X']         = X
    res['X_val']     = X_val
    res['y_lower']      = y_lower
    res['y_lower_val']  = y_lower_val
    res['y_upper']      = y_upper
    res['y_upper_val']  = y_upper_val
    return res

# %%
def trainModel(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower.values)
    dtrain.set_float_info("label_upper_bound",y_upper.values)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val.values)
    dtest.set_float_info("label_upper_bound",y_upper_val.values)
    
    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    min_val_error = round(np.min(res['test'][distributionCol]),4)
    return(min_val_error)

# %%
def objective(trial):
    SEED         = 1
    Kfolds       = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 10000
    res          = 0
    # Discrete-uniform parameter
    eta              = trial.suggest_discrete_uniform('eta',0.001,1.001,0.1)
    max_depth        = trial.suggest_discrete_uniform('max_depth',2, 10,2)
    min_child_weight = trial.suggest_discrete_uniform('min_child_weight',0.1,100.1,10)
    reg_alpha        = trial.suggest_loguniform('reg_alpha',0.0001,100)
    reg_lambda       = trial.suggest_loguniform('reg_lambda',0.0001,100)
    sigma            = trial.suggest_discrete_uniform('sigma',1,100,1)
    distribution     = trial.suggest_categorical('distribution',['normal','logistic','extreme'])
    
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res = res + trainModel(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    return res

# %%
def best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution): 
    SEED         = 1
    Kfolds        = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 10000
    # Discrete-uniform parameter
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    res_data = pd.DataFrame()
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res_data[fold_] = trainModelIter(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    res_data['total'] = res_data.sum(axis=1)
    num_round = res_data.idxmin(axis=0, skipna=True)['total']
    return num_round

# %%
data_name_domain = ['ATAC_JV_adipose','CTCF_TDH_ENCODE','H3K27ac-H3K4me3_TDHAM_BP','H3K27ac_TDH_some','H3K36me3_AM_immune']

# %%
data      = data_import(data_name_domain[4])
data_name = data_name_domain[4]

# %%
inputs = data['inputs']
labels = data['labels']
folds  = data['folds']

# %%
inputs,labels = data_massage(inputs,labels)

# %%
global X
global X_val
global y_lower
global y_upper
global y_upper_val

# %%
for fold in np.unique(folds['fold'].values):
    res          = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    study        = optuna.create_study()
    start        = time.time()
    study.optimize(objective, n_trials=100)
    trial         = study.best_trial
    json_filename = "../../../../result/"+data_name+"/xgboost/fold"+str(fold)+'_param.json'
    with open(json_filename, "w") as write_file:
        json.dump(trial.params, write_file)
# Out:
# [I 2019-12-08 09:02:09,857] Finished trial#0 resulted in value: 15.305400000000002. Current best value is 15.305400000000002 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 70.1, 'reg_alpha': 0.09384116644303464, 'reg_lambda': 0.5686535194620612, 'sigma': 19.0, 'distribution': 'logistic'}.
# [I 2019-12-08 09:02:24,070] Finished trial#1 resulted in value: 13.9263. Current best value is 13.9263 with parameters: {'eta': 0.201, 'max_depth': 2.0, 'min_child_weight': 70.1, 'reg_alpha': 0.008362495850362304, 'reg_lambda': 9.518741605366298, 'sigma': 21.0, 'distribution': 'extreme'}.
# [I 2019-12-08 09:02:34,305] Finished trial#2 resulted in value: 3.0123999999999995. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:02:44,146] Finished trial#3 resulted in value: 20.0687. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:02:55,549] Finished trial#4 resulted in value: 23.1222. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:03:09,692] Finished trial#5 resulted in value: 19.9807. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:03:20,823] Finished trial#6 resulted in value: 22.569300000000002. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:03:35,276] Finished trial#7 resulted in value: 15.169400000000001. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:03:46,776] Finished trial#8 resulted in value: 6.572100000000001. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:03:56,773] Finished trial#9 resulted in value: 19.8793. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:04:06,645] Finished trial#10 resulted in value: 18.178800000000003. Current best value is 3.0123999999999995 with parameters: {'eta': 0.501, 'max_depth': 10.0, 'min_child_weight': 50.1, 'reg_alpha': 0.0005828714772412579, 'reg_lambda': 1.7177202147186597, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:04:16,873] Finished trial#11 resulted in value: 3.0119999999999996. Current best value is 3.0119999999999996 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 40.1, 'reg_alpha': 0.0004106652551201309, 'reg_lambda': 0.012460070718884532, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:04:27,394] Finished trial#12 resulted in value: 3.0132000000000003. Current best value is 3.0119999999999996 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 40.1, 'reg_alpha': 0.0004106652551201309, 'reg_lambda': 0.012460070718884532, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:04:37,249] Finished trial#13 resulted in value: 16.784399999999998. Current best value is 3.0119999999999996 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 40.1, 'reg_alpha': 0.0004106652551201309, 'reg_lambda': 0.012460070718884532, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:04:48,474] Finished trial#14 resulted in value: 2.8451. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:04:58,316] Finished trial#15 resulted in value: 16.2805. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:05:08,141] Finished trial#16 resulted in value: 12.1936. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:05:18,007] Finished trial#17 resulted in value: 10.7731. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:05:27,902] Finished trial#18 resulted in value: 15.865599999999999. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:05:37,765] Finished trial#19 resulted in value: 18.4023. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:05:52,032] Finished trial#20 resulted in value: 9.803799999999999. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:06:02,290] Finished trial#21 resulted in value: 3.0123999999999995. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:06:12,523] Finished trial#22 resulted in value: 3.0125. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09:06:22,370] Finished trial#23 resulted in value: 14.5496. Current best value is 2.8451 with parameters: {'eta': 0.501, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0005714498459551884, 'reg_lambda': 0.013620692315148652, 'sigma': 2.0, 'distribution': 'normal'}.
# [I 2019-12-08 09
Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:13:21,564] Finished trial#70 resulted in value: 15.7013. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:13:31,982] Finished trial#71 resulted in value: 8.6249. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:13:42,389] Finished trial#72 resulted in value: 2.307. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:13:52,820] Finished trial#73 resulted in value: 8.6248. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:14:03,231] Finished trial#74 resulted in value: 8.625399999999999. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:14:13,651] Finished trial#75 resulted in value: 2.3067. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:14:24,034] Finished trial#76 resulted in value: 11.4922. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:14:36,248] Finished trial#77 resulted in value: inf. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:14:46,633] Finished trial#78 resulted in value: 15.2035. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:14:57,000] Finished trial#79 resulted in value: 21.0728. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:15:06,196] Finished trial#80 resulted in value: 6.3924. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:15:16,630] Finished trial#81 resulted in value: 2.3067. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:15:27,030] Finished trial#82 resulted in value: 7.566199999999999. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:15:37,454] Finished trial#83 resulted in value: 2.3065. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:15:47,855] Finished trial#84 resulted in value: 12.0121. Current best value is 2.3056 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.17527224549783602, 'reg_lambda': 6.648037876667341, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:15:58,295] Finished trial#85 resulted in value: 2.3055000000000003. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:16:08,696] Finished trial#86 resulted in value: 11.491800000000001. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:16:19,115] Finished trial#87 resulted in value: 7.566199999999999. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:16:29,505] Finished trial#88 resulted in value: 11.491800000000001. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:16:38,463] Finished trial#89 resulted in value: inf. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:16:48,849] Finished trial#90 resulted in value: 14.932599999999997. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:16:59,287] Finished trial#91 resulted in value: 2.3059000000000003. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:17:09,725] Finished trial#92 resulted in value: 7.5663. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:17:20,155] Finished trial#93 resulted in value: 2.3059. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:17:30,574] Finished trial#94 resulted in value: 11.491800000000001. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:17:41,016] Finished trial#95 resulted in value: 2.3068. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:17:51,447] Finished trial#96 resulted in value: 7.5663. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:18:01,874] Finished trial#97 resulted in value: 10.911299999999999. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:18:11,662] Finished trial#98 resulted in value: 26.5877. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 10:18:22,116] Finished trial#99 resulted in value: 2.307. Current best value is 2.3055000000000003 with parameters: {'eta': 1.001, 'max_depth': 6.0, 'min_child_weight': 70.1, 'reg_alpha': 0.0010482621548601316, 'reg_lambda': 6.628347196038062, 'sigma': 1.0, 'distribution': 'logistic'}.

# %%
def trainModelIter(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_upper)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_upper_val)

    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    val_error = res['test'][distributionCol]
    
    return(val_error)

# %%
#for fold in range(2,3):
for fold in np.unique(folds['fold'].values):
    res = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    json_filename = "../../../../result/"+data_name+"/xgboost/"+"fold"+str(fold)+'_param.json'
    with open(json_filename, errors='ignore') as json_data:
        json_fold = json.load(json_data, strict=False)
    eta = json_fold['eta']
    max_depth = json_fold['max_depth']
    min_child_weight = json_fold['min_child_weight']
    reg_alpha = json_fold['reg_alpha']
    reg_lambda = json_fold['reg_lambda']
    sigma= json_fold['sigma']
    distribution = json_fold['distribution'] 
    num_round = best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution)
    new_json = {}
    new_json['eta'] = eta
    new_json['max_depth'] = max_depth
    new_json['min_child_weight'] = min_child_weight
    new_json['reg_alpha'] = reg_alpha
    new_json['reg_lambda'] = reg_lambda
    new_json['sigma'] = sigma
    new_json['distribution'] = distribution
    new_json['num_round'] = int(num_round)
    json_filename = "../../../../result/"+data_name+"/xgboost/fold_new"+str(fold)+'_param.json'
    with open(json_filename, "w") as write_file:
         json.dump(new_json, write_file)
