# %%
import xgboost as xgb
import pandas  as pd
import numpy   as np
from   sklearn.model_selection import KFold
import optuna
import time
import json
from optuna.samplers import TPESampler
import functools

# %%
def data_import(data_name):
    filename = 'https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/'+data_name+'/'
    inputFileName = filename+'inputs.csv'
    labelFileName = filename+'outputs.csv'
    foldsFileName = filename+'cv/equal_labels/folds.csv'
    inputs        = pd.read_csv(inputFileName,index_col='sequenceID')
    labels        = pd.read_csv(labelFileName,index_col='sequenceID')
    folds         = pd.read_csv(foldsFileName,index_col='sequenceID')
    res           = {}
    res['inputs'] = inputs
    res['labels'] = labels
    res['folds']  = folds
    return(res)

# %%
def data_massage(inputs,labels):
    inputs.replace([-float('inf'),float('inf')],np.nan,inplace=True)
    missingCols = inputs.isnull().sum()
    missingCols = list(missingCols[missingCols>0].index)
    inputs.drop(missingCols,axis=1,inplace=True)
    varCols     = inputs.apply(lambda x: np.var(x))
    zeroVarCols = list(varCols[varCols==0].index)
    inputs.drop(zeroVarCols,axis=1,inplace=True)
    labels['min.log.lambda'] = labels['min.log.lambda'].apply(lambda x: np.exp(x))
    labels['max.log.lambda'] = labels['max.log.lambda'].apply(lambda x: np.exp(x))
    return inputs,labels

# %%
def getXY(foldNo,folds,inputs,labels):
    test_id       = list(folds[folds['fold']==foldNo].index)
    train_id      = list(folds[folds['fold']!=foldNo].index)
    X             = inputs[inputs.index.isin(train_id)]
    X_val         = inputs[inputs.index.isin(test_id)]
    y_label       = labels[labels.index.isin(train_id)]
    y_label_test  = labels[labels.index.isin(test_id)]
    y_lower       = y_label['min.log.lambda']
    y_upper       = y_label['max.log.lambda']
    y_lower_val   = y_label_test['min.log.lambda']
    y_upper_val   = y_label_test['max.log.lambda']
    res           = {}
    res['X']         = X
    res['X_val']     = X_val
    res['y_lower']      = y_lower
    res['y_lower_val']  = y_lower_val
    res['y_upper']      = y_upper
    res['y_upper_val']  = y_upper_val
    return res

# %%
def trainModel(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower.values)
    dtrain.set_float_info("label_upper_bound",y_upper.values)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val.values)
    dtest.set_float_info("label_upper_bound",y_upper_val.values)
    
    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    min_val_error = round(np.min(res['test'][distributionCol]),4)
    return(min_val_error)

# %%
def objective(distribution,trial):
    SEED         = 1
    Kfolds       = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 5000
    res          = 0
    # Discrete-uniform parameter
    eta              = trial.suggest_discrete_uniform('eta',0.001,1.001,0.1)
    max_depth        = trial.suggest_discrete_uniform('max_depth',2, 10,2)
    min_child_weight = trial.suggest_discrete_uniform('min_child_weight',0.1,100.1,10)
    reg_alpha        = trial.suggest_loguniform('reg_alpha',0.0001,100)
    reg_lambda       = trial.suggest_loguniform('reg_lambda',0.0001,100)
#     sigma            = trial.suggest_discrete_uniform('sigma',1,100,1)
#     distribution     = trial.suggest_categorical('distribution',['normal','logistic','extreme'])
    sigma            = 1
    
    distribution_sigma = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distribution_sigma
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res = res + trainModel(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distribution_sigma)
    return res

# %%
def best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution): 
    SEED          = 1
    Kfolds        = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round     = 5000
    # Discrete-uniform parameter
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }

    res_data = pd.DataFrame()
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res_data[fold_] = trainModelIter(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    res_data['total'] = res_data.sum(axis=1)
    res = {}
    num_round = res_data.idxmin(axis=0, skipna=True)['total']
    res['num_round'] = num_round
    res['min_val_error'] = min(res_data['total'])
    return res

# %%
data_name_domain = ['ATAC_JV_adipose','CTCF_TDH_ENCODE','H3K27ac-H3K4me3_TDHAM_BP','H3K27ac_TDH_some','H3K36me3_AM_immune']

# %%
data      = data_import(data_name_domain[0])
data_name = data_name_domain[0]

# %%
inputs = data['inputs']
labels = data['labels']
folds  = data['folds']

# %%
inputs,labels = data_massage(inputs,labels)

# %%
global X
global X_val
global y_lower
global y_upper
global y_upper_val

# %%
run_time = {}

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
for fold in np.unique(folds['fold'].values):
    
    start        = time.time()
    res          = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    
    for distribution in ['normal','logistic','extreme']:
        sampler = TPESampler(seed=1)  # Make the sampler behave in a deterministic way.
        study = optuna.create_study(sampler=sampler)
        study.optimize(functools.partial(objective,distribution), n_trials=100)
        trial         = study.best_trial
        json_filename = "../../../../result/"+data_name+"/xgboost/fold"+str(fold)+'_'+distribution+'_param.json'
        with open(json_filename, "w") as write_file:
            json.dump(trial.params, write_file)
    end            = time.time()
    time_taken     = end - start
    run_time[fold] = time_taken
# Out:
# [I 2019-12-17 02:55:54,861] Finished trial#0 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 02:56:02,612] Finished trial#1 resulted in value: 5.3451. Current best value is 5.3451 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 02:56:08,008] Finished trial#2 resulted in value: inf. Current best value is 5.3451 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 02:56:14,789] Finished trial#3 resulted in value: inf. Current best value is 5.3451 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 02:56:22,621] Finished trial#4 resulted in value: inf. Current best value is 5.3451 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 02:56:30,462] Finished trial#5 resulted in value: 5.1762999999999995. Current best value is 5.1762999999999995 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 02:56:36,874] Finished trial#6 resulted in value: 5.796399999999999. Current best value is 5.1762999999999995 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 02:56:43,112] Finished trial#7 resulted in value: 5.7929. Current best value is 5.1762999999999995 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 02:56:49,680] Finished trial#8 resulted in value: inf. Current best value is 5.1762999999999995 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 02:56:58,615] Finished trial#9 resulted in value: inf. Current best value is 5.1762999999999995 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 02:57:06,371] Finished trial#10 resulted in value: 5.207199999999999. Current best value is 5.1762999999999995 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 02:57:13,804] Finished trial#11 resulted in value: 5.1558. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:57:21,256] Finished trial#12 resulted in value: 5.2208000000000006. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:57:28,875] Finished trial#13 resulted in value: 5.6945. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:57:36,209] Finished trial#14 resulted in value: 5.2536. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:57:43,507] Finished trial#15 resulted in value: 5.639. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:57:50,814] Finished trial#16 resulted in value: 5.2344. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:57:57,596] Finished trial#17 resulted in value: inf. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:03,862] Finished trial#18 resulted in value: 5.7397. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:10,798] Finished trial#19 resulted in value: 5.2918. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:18,174] Finished trial#20 resulted in value: 5.434. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:25,610] Finished trial#21 resulted in value: 5.3358. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:33,047] Finished trial#22 resulted in value: 5.2676. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:40,386] Finished trial#23 resulted in value: 5.3102. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:47,682] Finished trial#24 resulted in value: 5.1642. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:58:55,016] Finished trial#25 resulted in value: 5.2614. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:02,359] Finished trial#26 resulted in value: 5.396400000000001. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:09,693] Finished trial#27 resulted in value: 5.1734. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:17,080] Finished trial#28 resulted in value: 5.356199999999999. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:24,391] Finished trial#29 resulted in value: 5.2831. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:31,776] Finished trial#30 resulted in value: 5.4849. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:39,216] Finished trial#31 resulted in value: 5.1874. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:46,618] Finished trial#32 resulted in value: 5.3308. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 02:59:53,920] Finished trial#33 resulted in value: 5.3675999999999995. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:01,228] Finished trial#34 resulted in value: 5.1966. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:08,541] Finished trial#35 resulted in value: 5.248399999999999. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:15,821] Finished trial#36 resulted in value: 5.3751. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:23,316] Finished trial#37 resulted in value: 5.2496. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:30,091] Finished trial#38 resulted in value: inf. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:37,439] Finished trial#39 resulted in value: 5.3308. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:42,630] Finished trial#40 resulted in value: inf. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:50,049] Finished trial#41 resulted in value: 5.2258000000000004. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:00:57,461] Finished trial#42 resulted in value: 5.2322. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:01:04,545] Finished trial#43 resulted in value: 5.8084. Current best value is 5.1558 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:01:11,875] Finished trial#44 resulted in value: 5.1404. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:01:19,186] Finished trial#45 resulted in value: 5.3073. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:01:26,525] Finished trial#46 resulted in value: 5.2385. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:01:33,820] Finished trial#47 resulted in value: 5.2833000000000006. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:01:41,176] Finished trial#48 resulted in value: 5.7246. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:01:48,735] Finished trial#49 resulted in value: 5.1905. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:01:56,025] Finished trial#50 resulted in value: 5.3625. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:03,510] Finished trial#51 resulted in value: 5.1415999999999995. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:10,865] Finished trial#52 resulted in value: 5.2138. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:18,270] Finished trial#53 resulted in value: 5.2413. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:24,583] Finished trial#54 resulted in value: 5.722300000000001. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:31,980] Finished trial#55 resulted in value: 5.1587. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:39,314] Finished trial#56 resulted in value: 5.235899999999999. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:46,973] Finished trial#57 resulted in value: 5.3502. Current best value is 5.1404 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.011284678698039771, 'reg_lambda': 38.038434815162304}.
# [I 2019-12-17 03:02:54,358] Finished trial#58 resulted in value: 5.106. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:01,696] Finished trial#59 resulted in value: 5.4571000000000005. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:09,039] Finished trial#60 resulted in value: 5.3714. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:16,374] Finished trial#61 resulted in value: 5.202299999999999. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:23,467] Finished trial#62 resulted in value: 5.2917000000000005. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:30,465] Finished trial#63 resulted in value: 5.2208000000000006. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:37,871] Finished trial#64 resulted in value: 5.1693. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:45,344] Finished trial#65 resulted in value: 5.192200000000001. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:52,634] Finished trial#66 resulted in value: 5.229299999999999. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:03:59,928] Finished trial#67 resulted in value: 5.6586. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:07,344] Finished trial#68 resulted in value: 5.1356. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:15,130] Finished trial#69 resulted in value: 5.2714. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:22,474] Finished trial#70 resulted in value: 5.2496. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:30,229] Finished trial#71 resulted in value: 5.2615. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:37,606] Finished trial#72 resulted in value: 5.299. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:45,074] Finished trial#73 resulted in value: 5.1778. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:52,424] Finished trial#74 resulted in value: 5.2864. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:04:59,760] Finished trial#75 resulted in value: 5.305300000000001. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:07,056] Finished trial#76 resulted in value: 5.3535. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:14,425] Finished trial#77 resulted in value: 5.195600000000001. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:21,840] Finished trial#78 resulted in value: 5.1884999999999994. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:28,878] Finished trial#79 resulted in value: 5.191299999999999. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:36,561] Finished trial#80 resulted in value: 5.3790000000000004. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:44,209] Finished trial#81 resulted in value: 5.2561. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:51,552] Finished trial#82 resulted in value: 5.1395. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:05:58,328] Finished trial#83 resulted in value: inf. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:06,243] Finished trial#84 resulted in value: 5.2069. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:13,561] Finished trial#85 resulted in value: 5.1832. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:20,874] Finished trial#86 resulted in value: 5.2604. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:28,477] Finished trial#87 resulted in value: 5.326099999999999. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:36,384] Finished trial#88 resulted in value: 5.3469. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:44,025] Finished trial#89 resulted in value: 5.1964999999999995. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:51,475] Finished trial#90 resulted in value: 5.202500000000001. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:06:58,822] Finished trial#91 resulted in value: 5.2153. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:06,482] Finished trial#92 resulted in value: 5.2959. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:13,858] Finished trial#93 resulted in value: 5.1802. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:21,190] Finished trial#94 resulted in value: 5.4126. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:28,728] Finished trial#95 resulted in value: 5.2079. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:35,503] Finished trial#96 resulted in value: inf. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:43,057] Finished trial#97 resulted in value: 5.2793. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:50,462] Finished trial#98 resulted in value: 5.3075. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:07:57,875] Finished trial#99 resulted in value: 5.1796999999999995. Current best value is 5.106 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 10.1, 'reg_alpha': 0.025901954964006834, 'reg_lambda': 25.276358976073716}.
# [I 2019-12-17 03:08:03,258] Finished trial#0 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:08:09,414] Finished trial#1 resulted in value: 457.5604. Current best value is 457.5604 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 03:08:14,671] Finished trial#2 resulted in value: inf. Current best value is 457.5604 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 03:08:19,871] Finished trial#3 resulted in value: inf. Current best value is 457.5604 with parameters: {'eta': 0.101, 'max_depth': 2.0, 'min_child_weight': 30.1, 'reg_alpha': 0.024021761202431626, 'reg_lambda': 0.17096232052870358}.
# [I 2019-12-17 03:08:27,264] Finished trial#4 resulted in value: 5.986700000000001. Current best value is 5.986700000000001 with parameters: {'eta': 0.801, 'max_depth': 10.0, 'min_child_weight': 30.1, 'reg_alpha': 1.425396519512469, 'reg_lambda': 18.12737477913364}.
# [I 2019-12-17 03:08:35,099] Finished trial#5 resulted in value: 5.769. Current best value is 5.769 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 03:08:41,251] Finished trial#6 resulted in value: 6.0563. Current best value is 5.769 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 03:08:47,381] Finished trial#7 resulted in value: 6.0564. Current best value is 5.769 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 03:08:52,618] Finished trial#8 resulted in value: inf. Current best value is 5.769 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 03:08:57,851] Finished trial#9 resulted in value: inf. Current best value is 5.769 with parameters: {'eta': 0.901, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0010446781646426277, 'reg_lambda': 18.57184372456476}.
# [I 2019-12-17 03:09:05,978] Finished trial#10 resulted in value: 5.750699999999999. Current best value is 5.750699999999999 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00011216477471547174, 'reg_lambda': 98.87076690511398}.
# [I 2019-12-17 03:09:13,810] Finished trial#11 resulted in value: 5.7378. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:21,668] Finished trial#12 resulted in value: 5.755199999999999. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:27,796] Finished trial#13 resulted in value: 6.054. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:33,042] Finished trial#14 resulted in value: inf. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:39,153] Finished trial#15 resulted in value: 947.3703. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:46,622] Finished trial#16 resulted in value: 5.8345. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:54,334] Finished trial#17 resulted in value: 5.8325. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:09:59,590] Finished trial#18 resulted in value: inf. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:05,748] Finished trial#19 resulted in value: 9.3601. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:11,918] Finished trial#20 resulted in value: 6.6034999999999995. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:19,755] Finished trial#21 resulted in value: 5.7516. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:27,603] Finished trial#22 resulted in value: 5.7477. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:33,767] Finished trial#23 resulted in value: 299.497. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:41,490] Finished trial#24 resulted in value: 5.829200000000001. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:47,611] Finished trial#25 resulted in value: 1185.3800999999999. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:10:53,781] Finished trial#26 resulted in value: 6.053. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:01,523] Finished trial#27 resulted in value: 5.8468. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:09,104] Finished trial#28 resulted in value: 5.931800000000001. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:16,945] Finished trial#29 resulted in value: 5.8464. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:22,203] Finished trial#30 resulted in value: inf. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:30,049] Finished trial#31 resulted in value: 5.7531. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:37,755] Finished trial#32 resulted in value: 5.8366999999999996. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:45,607] Finished trial#33 resulted in value: 5.7620000000000005. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:11:53,208] Finished trial#34 resulted in value: 5.925. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:12:00,919] Finished trial#35 resulted in value: 5.8311. Current best value is 5.7378 with parameters: {'eta': 1.001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00013142975293492504, 'reg_lambda': 37.57818563000278}.
# [I 2019-12-17 03:12:08,800] Finished trial#36 resulted in value: 5.734299999999999. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:16,452] Finished trial#37 resulted in value: 5.9592. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:21,710] Finished trial#38 resulted in value: inf. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:27,842] Finished trial#39 resulted in value: 982.4375. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:35,579] Finished trial#40 resulted in value: 5.8291. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:42,064] Finished trial#41 resulted in value: 16.3482. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:49,920] Finished trial#42 resulted in value: 6.001099999999999. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:12:57,636] Finished trial#43 resulted in value: 5.8414. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:04,454] Finished trial#44 resulted in value: 6.2894. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:10,626] Finished trial#45 resulted in value: 6.0521. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:16,802] Finished trial#46 resulted in value: 691.7044999999999. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:24,212] Finished trial#47 resulted in value: 5.9876000000000005. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:29,460] Finished trial#48 resulted in value: inf. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:37,314] Finished trial#49 resulted in value: 5.752999999999999. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:44,469] Finished trial#50 resulted in value: 5.8086. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:13:52,431] Finished trial#51 resulted in value: 5.7471. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:00,338] Finished trial#52 resulted in value: 5.748600000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:08,268] Finished trial#53 resulted in value: 5.744. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:16,014] Finished trial#54 resulted in value: 5.796200000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:23,879] Finished trial#55 resulted in value: 5.7508. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:31,749] Finished trial#56 resulted in value: 5.7376000000000005. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:37,912] Finished trial#57 resulted in value: 351.92289999999997. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:44,076] Finished trial#58 resulted in value: 6.0534. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:51,745] Finished trial#59 resulted in value: 5.9384999999999994. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:14:59,491] Finished trial#60 resulted in value: 5.833900000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:07,449] Finished trial#61 resulted in value: 5.736700000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:15,302] Finished trial#62 resulted in value: 5.7524999999999995. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:23,185] Finished trial#63 resulted in value: 5.7583. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:29,656] Finished trial#64 resulted in value: 16.385599999999997. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:37,377] Finished trial#65 resulted in value: 5.8238. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:45,250] Finished trial#66 resulted in value: 5.755700000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:15:52,991] Finished trial#67 resulted in value: 5.828200000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:00,761] Finished trial#68 resulted in value: 5.8365. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:08,965] Finished trial#69 resulted in value: 5.7603. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:16,639] Finished trial#70 resulted in value: 5.942000000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:24,522] Finished trial#71 resulted in value: 5.7505. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:32,430] Finished trial#72 resulted in value: 5.742700000000001. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:40,318] Finished trial#73 resulted in value: 5.7485. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:48,203] Finished trial#74 resulted in value: 5.7539. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:16:55,943] Finished trial#75 resulted in value: 5.8216. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:17:03,824] Finished trial#76 resulted in value: 5.9159. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:17:11,422] Finished trial#77 resulted in value: 8.013. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:17:19,170] Finished trial#78 resulted in value: 5.8396. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:17:27,054] Finished trial#79 resulted in value: 5.7593. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:17:34,820] Finished trial#80 resulted in value: 5.8481000000000005. Current best value is 5.734299999999999 with parameters: {'eta': 0.7010000000000001, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.00020078617615419255, 'reg_lambda': 18.992502305917405}.
# [I 2019-12-17 03:17:42,704] Finished trial#81 resulted in value: 5.7341999999999995. Current best value is 5.7341999999999995 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0002384067870449454, 'reg_lambda': 58.2470467798314}.
# [I 2019-12-17 03:17:48,915] Finished trial#82 resulted in value: 6.0529. Current best value is 5.7341999999999995 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0002384067870449454, 'reg_lambda': 58.2470467798314}.
# [I 2019-12-17 03:17:56,799] Finished trial#83 resulted in value: 5.7447. Current best value is 5.7341999999999995 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0002384067870449454, 'reg_lambda': 58.2470467798314}.
# [I 2019-12-17 03:18:04,688] Finished trial#84 resulted in value: 5.7562. Current best value is 5.7341999999999995 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0002384067870449454, 'reg_lambda': 58.2470467798314}.
# [I 2019-12-17 03:18:12,594] Finished trial#85 resulted in value: 5.7586. Current best value is 5.7341999999999995 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.0002384067870449454, 'reg_lambda': 58.2470467798314}.
# ...
# [I 2019-12-17 03:57:49,354] Finished trial#35 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:57:56,109] Finished trial#36 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:02,857] Finished trial#37 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:09,620] Finished trial#38 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:16,367] Finished trial#39 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:23,108] Finished trial#40 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:29,860] Finished trial#41 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:36,588] Finished trial#42 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:43,322] Finished trial#43 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:50,061] Finished trial#44 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:58:56,807] Finished trial#45 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:03,638] Finished trial#46 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:10,375] Finished trial#47 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:17,119] Finished trial#48 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:23,935] Finished trial#49 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:30,688] Finished trial#50 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:37,449] Finished trial#51 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:44,203] Finished trial#52 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:50,962] Finished trial#53 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 03:59:57,707] Finished trial#54 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:04,466] Finished trial#55 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:11,234] Finished trial#56 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:18,018] Finished trial#57 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:24,772] Finished trial#58 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:31,535] Finished trial#59 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:38,286] Finished trial#60 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:45,009] Finished trial#61 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:51,757] Finished trial#62 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:00:58,508] Finished trial#63 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:05,285] Finished trial#64 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:12,064] Finished trial#65 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:18,836] Finished trial#66 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:25,654] Finished trial#67 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:32,462] Finished trial#68 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:39,213] Finished trial#69 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:46,005] Finished trial#70 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:52,769] Finished trial#71 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:01:59,543] Finished trial#72 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:06,319] Finished trial#73 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:13,095] Finished trial#74 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:19,854] Finished trial#75 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:26,612] Finished trial#76 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:33,404] Finished trial#77 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:40,173] Finished trial#78 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:46,934] Finished trial#79 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:02:53,692] Finished trial#80 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:00,455] Finished trial#81 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:07,243] Finished trial#82 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:14,023] Finished trial#83 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:20,792] Finished trial#84 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:27,584] Finished trial#85 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:34,354] Finished trial#86 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:41,115] Finished trial#87 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:47,878] Finished trial#88 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:03:54,636] Finished trial#89 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:01,410] Finished trial#90 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:08,181] Finished trial#91 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:14,962] Finished trial#92 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:21,727] Finished trial#93 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:28,490] Finished trial#94 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:35,267] Finished trial#95 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:42,036] Finished trial#96 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:48,804] Finished trial#97 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:04:55,583] Finished trial#98 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.
# [I 2019-12-17 04:05:02,378] Finished trial#99 resulted in value: inf. Current best value is inf with parameters: {'eta': 0.401, 'max_depth': 8.0, 'min_child_weight': 0.1, 'reg_alpha': 0.006516215458215695, 'reg_lambda': 0.0007595132328682402}.

# %%
json_filename = "../../../../result/"+data_name+"/xgboost/run_time_tuning1.json"
with open(json_filename, "w") as write_file:
    json.dump(run_time, write_file)

# %%
def trainModelIter(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_upper)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_upper_val)

    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    val_error = res['test'][distributionCol]
    
    return(val_error)

# %%
run_time2 = {}

# %%
#for fold in range(2,3):
for fold in np.unique(folds['fold'].values):
    start_time   = time.time()
    res = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    
    for distribution in ['normal','logistic','extreme']:
        json_filename = "../../../../result/"+data_name+"/xgboost/fold"+str(fold)+'_'+distribution+'_param.json'
        with open(json_filename, errors='ignore') as json_data:
            json_fold = json.load(json_data, strict=False)
        eta = json_fold['eta']
        max_depth = json_fold['max_depth']
        min_child_weight = json_fold['min_child_weight']
        reg_alpha = json_fold['reg_alpha']
        reg_lambda = json_fold['reg_lambda']
        sigma= 1
        res      = best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution)
        new_json = {}
        new_json['eta'] = eta
        new_json['max_depth'] = max_depth
        new_json['min_child_weight'] = min_child_weight
        new_json['reg_alpha']     = reg_alpha
        new_json['reg_lambda']    = reg_lambda
        new_json['sigma']         = sigma
        new_json['distribution']  = distribution
        new_json['num_round']     = int(res['num_round'])
        if res['min_val_error'] == float('inf'):
            res['min_val_error'] = 10**8
        new_json['min_val_error'] = res['min_val_error']
        json_filename = "../../../../result/"+data_name+"/xgboost/fold_new"+str(fold)+'_'+distribution+'_param.json'
        with open(json_filename, "w") as write_file:
             json.dump(new_json, write_file)
    end_time        = time.time()
    time_taken      = end_time - start_time
    run_time2[fold] = time_taken

# %% [markdown]
# ### Choosing best hyperparameter

# %%
#for fold in range(2,3):
for fold in np.unique(folds['fold'].values):
    fold_data = pd.DataFrame()
    for distribution in ['normal','logistic','extreme']:
        json_filename = "../../../../result/"+data_name+"/xgboost/fold_new"+str(fold)+'_'+distribution+'_param.json'
        with open(json_filename, errors='ignore') as json_data:
            json_fold = json.load(json_data, strict=False)
        dist_data = pd.DataFrame.from_dict(json_fold,orient='index',columns=[distribution])
        fold_data = pd.concat([fold_data,dist_data],axis=1)
    fold_data = fold_data.transpose()
    fold_data['min_val_error'] = fold_data['min_val_error'].astype('float')
    best_dis   = fold_data['min_val_error'].idxmin()
    best_param = fold_data.loc[best_dis]
    json_filename = "../../../../result/"+data_name+"/xgboost/fold_new"+str(fold)+'_dis'+'_param.json'
    best_param = best_param.to_dict()
    with open(json_filename, "w") as write_file:
        json.dump(best_param, write_file)

# %%
run_time3 ={}
for key in run_time2.keys():
    run_time3[str(key)] = run_time2[key]

# %%
json_filename = "../../../../result/"+data_name+"/xgboost/run_time_tuning2.json"
with open(json_filename, "w") as write_file:
    json.dump(run_time3, write_file)
