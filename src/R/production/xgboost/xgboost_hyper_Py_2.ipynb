# %%
import xgboost as xgb
import pandas  as pd
import numpy   as np
from   sklearn.model_selection import KFold
import optuna
import time
import json

# %%
def data_import(data_name):
    filename = 'https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/'+data_name+'/'
    inputFileName = filename+'inputs.csv'
    labelFileName = filename+'outputs.csv'
    foldsFileName = filename+'cv/equal_labels/folds.csv'
    inputs        = pd.read_csv(inputFileName,index_col='sequenceID')
    labels        = pd.read_csv(labelFileName,index_col='sequenceID')
    folds         = pd.read_csv(foldsFileName,index_col='sequenceID')
    res           = {}
    res['inputs'] = inputs
    res['labels'] = labels
    res['folds']  = folds
    return(res)

# %%
def data_massage(inputs,labels):
    inputs.replace([-float('inf'),float('inf')],np.nan,inplace=True)
    missingCols = inputs.isnull().sum()
    missingCols = list(missingCols[missingCols>0].index)
    inputs.drop(missingCols,axis=1,inplace=True)
    varCols     = inputs.apply(lambda x: np.var(x))
    zeroVarCols = list(varCols[varCols==0].index)
    inputs.drop(zeroVarCols,axis=1,inplace=True)
    labels['min.log.lambda'] = labels['min.log.lambda'].apply(lambda x: np.exp(x))
    labels['max.log.lambda'] = labels['max.log.lambda'].apply(lambda x: np.exp(x))
    return inputs,labels

# %%
def getXY(foldNo,folds,inputs,labels):
    test_id       = list(folds[folds['fold']==foldNo].index)
    train_id      = list(folds[folds['fold']!=foldNo].index)
    X             = inputs[inputs.index.isin(train_id)]
    X_val         = inputs[inputs.index.isin(test_id)]
    y_label       = labels[labels.index.isin(train_id)]
    y_label_test  = labels[labels.index.isin(test_id)]
    y_lower       = y_label['min.log.lambda']
    y_upper       = y_label['max.log.lambda']
    y_lower_val   = y_label_test['min.log.lambda']
    y_upper_val   = y_label_test['max.log.lambda']
    res           = {}
    res['X']         = X
    res['X_val']     = X_val
    res['y_lower']      = y_lower
    res['y_lower_val']  = y_lower_val
    res['y_upper']      = y_upper
    res['y_upper_val']  = y_upper_val
    return res

# %%
def trainModel(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower.values)
    dtrain.set_float_info("label_upper_bound",y_upper.values)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val.values)
    dtest.set_float_info("label_upper_bound",y_upper_val.values)
    
    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    min_val_error = round(np.min(res['test'][distributionCol]),4)
    return(min_val_error)

# %%
def objective(trial):
    SEED         = 1
    Kfolds       = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 10000
    res          = 0
    # Discrete-uniform parameter
    eta              = trial.suggest_discrete_uniform('eta',0.001,1.001,0.1)
    max_depth        = trial.suggest_discrete_uniform('max_depth',2, 10,2)
    min_child_weight = trial.suggest_discrete_uniform('min_child_weight',0.1,100.1,10)
    reg_alpha        = trial.suggest_loguniform('reg_alpha',0.0001,100)
    reg_lambda       = trial.suggest_loguniform('reg_lambda',0.0001,100)
    sigma            = trial.suggest_discrete_uniform('sigma',1,100,1)
    distribution     = trial.suggest_categorical('distribution',['normal','logistic','extreme'])
    
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res = res + trainModel(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    return res

# %%
def best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution): 
    SEED         = 1
    Kfolds        = KFold(n_splits=5,shuffle=True,random_state=SEED)
    num_round    = 10000
    # Discrete-uniform parameter
    distributionCol = distribution+ ',' + str(sigma)
    eval_metric     = 'aft-nloglik@'+distributionCol
    base_score      = 0.5
    
    params   = {
                'eta':eta,
                'max_depth':int(max_depth),
                'min_child_weight':min_child_weight,
                'subsample':0.7,
                'reg_alpha':reg_alpha,
                'reg_lambda':reg_lambda,
                'aft_noise_distribution' : distribution, 
                'aft_sigma': sigma,
                'eval_metric':eval_metric,
                'base_score':base_score,
                'objective':"aft:survival",
                'verbosity': 0
                }
    res_data = pd.DataFrame()
    for fold_, (trn_idx, val_idx) in enumerate(Kfolds.split(X, y_lower,y_upper)):
        tr_x, tr_y_lower,tr_y_upper = X.iloc[trn_idx,:],y_lower.iloc[trn_idx],y_upper.iloc[trn_idx]
        vl_x, vl_y_lower,vl_y_upper = X.iloc[val_idx,:], y_lower.iloc[val_idx],y_upper.iloc[val_idx]
        res_data[fold_] = trainModelIter(tr_x,vl_x,tr_y_lower,tr_y_upper,vl_y_lower,vl_y_upper,params,num_round,distributionCol)
    res_data['total'] = res_data.sum(axis=1)
    num_round = res_data.idxmin(axis=0, skipna=True)['total']
    return num_round

# %%
data_name_domain = ['ATAC_JV_adipose','CTCF_TDH_ENCODE','H3K27ac-H3K4me3_TDHAM_BP','H3K27ac_TDH_some','H3K36me3_AM_immune']

# %%
data      = data_import(data_name_domain[2])
data_name = data_name_domain[2]

# %%
inputs = data['inputs']
labels = data['labels']
folds  = data['folds']

# %%
inputs,labels = data_massage(inputs,labels)

# %%
global X
global X_val
global y_lower
global y_upper
global y_upper_val

# %%
for fold in np.unique(folds['fold'].values):
    res          = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    study        = optuna.create_study()
    start        = time.time()
    study.optimize(objective, n_trials=100)
    trial         = study.best_trial
    json_filename = "../../../../result/"+data_name+"/xgboost/fold"+str(fold)+'_param.json'
    with open(json_filename, "w") as write_file:
        json.dump(trial.params, write_file)
# Out:
# [I 2019-12-08 03:38:30,715] Finished trial#0 resulted in value: 8.152. Current best value is 8.152 with parameters: {'eta': 0.7010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.007931803690659737, 'reg_lambda': 0.041168087488223495, 'sigma': 46.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:38:55,460] Finished trial#1 resulted in value: 8.3767. Current best value is 8.152 with parameters: {'eta': 0.7010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.007931803690659737, 'reg_lambda': 0.041168087488223495, 'sigma': 46.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:39:24,066] Finished trial#2 resulted in value: 8.6226. Current best value is 8.152 with parameters: {'eta': 0.7010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.007931803690659737, 'reg_lambda': 0.041168087488223495, 'sigma': 46.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:39:52,312] Finished trial#3 resulted in value: 10.593699999999998. Current best value is 8.152 with parameters: {'eta': 0.7010000000000001, 'max_depth': 6.0, 'min_child_weight': 90.1, 'reg_alpha': 0.007931803690659737, 'reg_lambda': 0.041168087488223495, 'sigma': 46.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:40:29,674] Finished trial#4 resulted in value: 8.0975. Current best value is 8.0975 with parameters: {'eta': 0.30100000000000005, 'max_depth': 10.0, 'min_child_weight': 10.1, 'reg_alpha': 56.6308531189176, 'reg_lambda': 0.0017716315279209098, 'sigma': 11.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:40:54,613] Finished trial#5 resulted in value: 8.0243. Current best value is 8.0243 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.6058465173912675, 'reg_lambda': 0.2274503611254702, 'sigma': 48.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:41:22,989] Finished trial#6 resulted in value: 9.8103. Current best value is 8.0243 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.6058465173912675, 'reg_lambda': 0.2274503611254702, 'sigma': 48.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:41:47,746] Finished trial#7 resulted in value: 9.7609. Current best value is 8.0243 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.6058465173912675, 'reg_lambda': 0.2274503611254702, 'sigma': 48.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:42:16,199] Finished trial#8 resulted in value: 8.3331. Current best value is 8.0243 with parameters: {'eta': 0.801, 'max_depth': 2.0, 'min_child_weight': 0.1, 'reg_alpha': 0.6058465173912675, 'reg_lambda': 0.2274503611254702, 'sigma': 48.0, 'distribution': 'normal'}.
# [I 2019-12-08 03:42:54,218] Finished trial#9 resulted in value: 3.6207999999999996. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:43:31,193] Finished trial#10 resulted in value: 6.148999999999999. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:44:08,138] Finished trial#11 resulted in value: 5.4708. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:44:45,226] Finished trial#12 resulted in value: 3.8326000000000002. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:45:22,241] Finished trial#13 resulted in value: 7.678899999999999. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:45:59,305] Finished trial#14 resulted in value: 7.3734. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:46:36,446] Finished trial#15 resulted in value: 4.2474. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:47:13,737] Finished trial#16 resulted in value: 3.8128. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03:47:50,624] Finished trial#17 resulted in value: 11.9359. Current best value is 3.6207999999999996 with parameters: {'eta': 0.001, 'max_depth': 8.0, 'min_child_weight': 80.1, 'reg_alpha': 0.01812511189227898, 'reg_lambda': 1.4064351610206767, 'sigma': 2.0, 'distribution': 'extreme'}.
# [I 2019-12-08 03
Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:52:27,905] Finished trial#67 resulted in value: 7.8557. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:52:49,947] Finished trial#68 resulted in value: 11.6943. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:53:12,024] Finished trial#69 resulted in value: 10.017900000000001. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:53:34,405] Finished trial#70 resulted in value: 7.859. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:53:56,721] Finished trial#71 resulted in value: 10.435400000000001. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:54:18,479] Finished trial#72 resulted in value: 365.5139. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:54:40,542] Finished trial#73 resulted in value: 9.7867. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:55:02,837] Finished trial#74 resulted in value: 12.0891. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:55:25,117] Finished trial#75 resulted in value: 8.5633. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:56:08,544] Finished trial#76 resulted in value: inf. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:56:30,940] Finished trial#77 resulted in value: 9.763100000000001. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:56:53,114] Finished trial#78 resulted in value: 7.8561. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:57:15,195] Finished trial#79 resulted in value: 11.927399999999999. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:57:37,159] Finished trial#80 resulted in value: 14.012400000000001. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:57:59,330] Finished trial#81 resulted in value: 9.7625. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:58:21,100] Finished trial#82 resulted in value: 423.4067. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:58:43,310] Finished trial#83 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:59:05,400] Finished trial#84 resulted in value: 15.095399999999998. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:59:27,622] Finished trial#85 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 06:59:49,679] Finished trial#86 resulted in value: 10.997699999999998. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:00:11,864] Finished trial#87 resulted in value: 9.4805. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:00:34,049] Finished trial#88 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:00:59,178] Finished trial#89 resulted in value: 8.7566. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:01:21,448] Finished trial#90 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:01:43,695] Finished trial#91 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:02:02,006] Finished trial#92 resulted in value: inf. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:02:24,174] Finished trial#93 resulted in value: 9.4801. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:02:46,422] Finished trial#94 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:03:07,954] Finished trial#95 resulted in value: 343.1009. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:03:30,118] Finished trial#96 resulted in value: 9.4812. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:03:52,203] Finished trial#97 resulted in value: 10.6502. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:04:14,417] Finished trial#98 resulted in value: 7.8575. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.
# [I 2019-12-08 07:04:36,583] Finished trial#99 resulted in value: 10.4573. Current best value is 5.059699999999999 with parameters: {'eta': 0.001, 'max_depth': 2.0, 'min_child_weight': 50.1, 'reg_alpha': 0.05770273182133758, 'reg_lambda': 0.47362712697249754, 'sigma': 1.0, 'distribution': 'logistic'}.

# %%
def trainModelIter(X,X_val,y_lower,y_upper,y_lower_val,y_upper_val,params,num_round,distributionCol):
    
    res    = {}
    dtrain = xgb.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_upper)

    dtest  = xgb.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_upper_val)

    bst    = xgb.train(params,dtrain,num_boost_round=num_round,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res,verbose_eval=False)
    val_error = res['test'][distributionCol]
    
    return(val_error)

# %%
#for fold in range(2,3):
for fold in np.unique(folds['fold'].values):
    res = getXY(fold,folds,inputs,labels)
    X            = res['X']        
    X_val        = res['X_val']
    y_lower      = res['y_lower']
    y_lower_val  = res['y_lower_val']
    y_upper      = res['y_upper']
    y_upper_val  = res['y_upper_val']
    json_filename = "../../../../result/"+data_name+"/xgboost/"+"fold"+str(fold)+'_param.json'
    with open(json_filename, errors='ignore') as json_data:
        json_fold = json.load(json_data, strict=False)
    eta = json_fold['eta']
    max_depth = json_fold['max_depth']
    min_child_weight = json_fold['min_child_weight']
    reg_alpha = json_fold['reg_alpha']
    reg_lambda = json_fold['reg_lambda']
    sigma= json_fold['sigma']
    distribution = json_fold['distribution'] 
    num_round = best_iter(eta,max_depth,min_child_weight,reg_alpha,reg_lambda,sigma,distribution)
    new_json = {}
    new_json['eta'] = eta
    new_json['max_depth'] = max_depth
    new_json['min_child_weight'] = min_child_weight
    new_json['reg_alpha'] = reg_alpha
    new_json['reg_lambda'] = reg_lambda
    new_json['sigma'] = sigma
    new_json['distribution'] = distribution
    new_json['num_round'] = int(num_round)
    json_filename = "../../../../result/"+data_name+"/xgboost/fold_new"+str(fold)+'_param.json'
    with open(json_filename, "w") as write_file:
         json.dump(new_json, write_file)
