# %%
library(mboost)
library(survival)
library(penaltyLearning)
library(Hmisc)
library(caret)
library(rjson)
# Out:
# Loading required package: parallel
#
# Loading required package: stabs
#
# This is mboost 2.9-1. See ‘package?mboost’ and ‘news(package  = "mboost")’
# for a complete list of changes.
#
#
# Loading required package: lattice
#
# Loading required package: Formula
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘ggplot2’
#
#
# The following object is masked from ‘package:mboost’:
#
#     %+%
#
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
#
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:survival’:
#
#     cluster

# %%
data_import =function(dataname){
  filename = paste('https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/',dataname,'/',sep="")
  inputFileName = paste(filename,'inputs.csv',sep="")
  labelFileName = paste(filename,'outputs.csv',sep="")
  foldsFileName = paste(filename,'cv/equal_labels/folds.csv',sep="")
  inputs        = read.table(inputFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
  labels        = read.table(labelFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
  folds         = read.table(foldsFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
  res           = list()
  res$inputs    = inputs
  res$labels    = labels
  res$folds     = folds
  return(res)
}

# %%
data_massage = function(inputs,labels){
    rownamesInput = rownames(inputs)
    inputs        = do.call(data.frame,lapply(inputs, function(x) replace(x, is.infinite(x),NA)))
    naColumns     = colnames(inputs)[colSums(is.na(inputs))>0]
    noVarCol      = getNonVarCols(inputs)
    removeCols    = c(naColumns,noVarCol)
    inputs        = inputs[ , !(colnames(inputs) %in% removeCols)]
    rownames(inputs) = rownamesInput
    labels$min.log.lambda = unlist(lapply(labels$min.log.lambda,exp))
    labels$max.log.lambda = unlist(lapply(labels$max.log.lambda,exp))
    res        = list()
    res$inputs = inputs
    res$labels = labels
    return(res)
}

# %%
getXY<-function(foldNo,folds,inputs,labels){
    test.id       = rownames(subset(folds,fold==foldNo))
    train.id      = rownames(subset(folds,fold!=foldNo))
    X             = subset(inputs,rownames(inputs) %in% train.id)
    X             = as.matrix(X)
    X.val         = subset(inputs,rownames(inputs) %in% test.id)
    X.val         = as.matrix(X.val)
    y.label       = subset(labels,rownames(labels) %in% train.id)
    y.label.test  = subset(labels,rownames(labels) %in% test.id)
    y.lower       = as.matrix(y.label$min.log.lambda)
    y.upper       = as.matrix(y.label$max.log.lambda)
    y.lower.val   = as.matrix(y.label.test$min.log.lambda)
    y.upper.val   = as.matrix(y.label.test$max.log.lambda)
    res           = list()
    res$X         = X
    res$X.val     = X.val
    res$y.lower      = y.lower
    res$y.lower.val  = y.lower.val
    res$y.upper      = y.upper
    res$y.upper.val  = y.upper.val
    return(res)
}

# %%
getNonVarCols<-function(data){
    var_columns    = apply(inputs,2,var)
    resCol         = names(var_columns[var_columns==0.0])
    return(resCol)
}

# %%
# Set Parameters
dataNameRange       = c('ATAC_JV_adipose','CTCF_TDH_ENCODE','H3K27ac-H3K4me3_TDHAM_BP','H3K27ac_TDH_some','H3K36me3_AM_immune')
sigma_range         = c(1,2,5,10,100)
distribution_range  = c('normal','logistic','extreme')
learning_rate       = 0.1
num_round           = 200

# %%
res                 = data_import(dataNameRange[1])
inputs              = res$inputs
labels              = res$labels
folds               = res$folds
resDataMassage      = data_massage(inputs,labels)
inputs              = resDataMassage$inputs
labels              = resDataMassage$labels
fold_iter           = unique(folds$fold)
accuracy_fold       = numeric(length(fold_iter))

# %%
getaccuracy=function(pred,y_lower,y_higher){
    res = (pred>=y_lower & pred<=y_higher)
    return(res)
}

# %%
for(i in 1:length(fold_iter)){
    res                 = getXY(fold_iter[i],folds,inputs,labels)
    X                   = res$X
    X.val               = res$X.val
    y.lower             = log(res$y.lower)
    y.lower.val         = log(res$y.lower.val)
    y.upper             = log(res$y.upper)
    y.upper.val         = log(res$y.upper.val)
    train.folds         = cut(seq(1,nrow(X)),breaks=5,labels=FALSE)
    res                 = list()
    target.mat          = cbind(y.lower,y.upper)
    fit                 = IntervalRegressionCV(X, target.mat)  
    pred.y.val          = predict(fit, X.val)
    pred_data           = data.frame(pred.y.val,y.lower.val,y.upper.val)
    colnames(pred_data) = c("predict","y.lower","y.upper")
    accuracy_fold[i] = sum(mapply(getaccuracy,pred.y.val,y.lower.val,y.upper.val))/length(pred.y.val)
    fileName            = paste('../../../../result/ATAC_JV_adipose/intervalCV/',i,".csv")
    write.table(pred_data,fileName,sep=",",col.names=NA)
}
# Out:
# Loading required namespace: future.apply
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: future.apply
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: future.apply
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: future.apply
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight
#
# Loading required namespace: directlabels
#
# install.packages("directlabels") for more informative labels on plot.weight

# %% [markdown]
# # Save Accuracy

# %%
jsonAccuracy = toJSON(accuracy_fold)

# %%
write(jsonAccuracy, file="../../../../result/ATAC_JV_adipose/intervalCV/accuracy.JSON")

# %% [markdown]
# # Compare Results

# %%
resFileName = "https://raw.githubusercontent.com/tdhock/neuroblastoma-data/master/data/ATAC_JV_adipose/cv/equal_labels/testFolds/1/randomTrainOrderings/1/models/L1reg_linear_all/predictions.csv"

# %%
out_res_fold1 = read.table(resFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
out_res_fold1 = out_res_fold1[ order(row.names(out_res_fold1)), ]

# %%
fileName      = paste('../../../../result/ATAC_JV_adipose/intervalCV/',1,".csv")
in_res_fold1  = read.table(fileName,sep=",",header=T,stringsAsFactors = F,row.names=1)
in_res_fold1  = in_res_fold1[ order(row.names(in_res_fold1)),]

# %%
seq_in  = rownames(in_res_fold1)
seq_out = rownames(out_res_fold1)

# %%
identical(seq_in,seq_out)
# Out:
# [1] FALSE

# %%
out_res_fold1 = data.frame(out_res_fold1[,"X335"], row.names=rownames(out_res_fold1))

# %%
colnames(out_res_fold1) = c("pred.out")

# %%
in_res_fold1 = data.frame(in_res_fold1[,"predict"], row.names=rownames(in_res_fold1))

# %%
colnames(in_res_fold1) = c("pred.in")

# %%
merge(x = in_res_fold1, y = out_res_fold1, by = "row.names", all = TRUE)
# Out:
#     Row.names
# 1   ATAC_JV_adipose/samples/AC1/MSC77/problems/chr10:18024675-38818835
# 2   ATAC_JV_adipose/samples/AC1/MSC77/problems/chr11:69774695-87688378
# 3   ATAC_JV_adipose/samples/AC1/MSC77/problems/chr14:19050000-107289540
# 4   ATAC_JV_adipose/samples/AC1/MSC77/problems/chr4:75452279-190000000
# 5   ATAC_JV_adipose/samples/AC1/MSC80/problems/chr10:18024675-38818835
# 6   ATAC_JV_adipose/samples/AC1/MSC80/problems/chr11:69774695-87688378
# 7   ATAC_JV_adipose/samples/AC1/MSC80/problems/chr14:19050000-107289540
# 8   ATAC_JV_adipose/samples/AC1/MSC80/problems/chr4:75452279-190000000
# 9   ATAC_JV_adipose/samples/AC1/MSC83/problems/chr10:18024675-38818835
# 10  ATAC_JV_adipose/samples/AC1/MSC83/problems/chr11:69774695-87688378
# 11  ATAC_JV_adipose/samples/AC1/MSC83/problems/chr14:19050000-107289540
# 12  ATAC_JV_adipose/samples/AC1/MSC83/problems/chr4:75452279-190000000
# 13  ATAC_JV_adipose/samples/AC1/MSC91/problems/chr10:18024675-38818835
# 14  ATAC_JV_adipose/samples/AC1/MSC91/problems/chr11:69774695-87688378
# 15  ATAC_JV_adipose/samples/AC1/MSC91/problems/chr14:19050000-107289540
# 16  ATAC_JV_adipose/samples/AC1/MSC91/problems/chr4:75452279-190000000
# 17  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr1:521368-2634220
# 18  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr10:18024675-38818835
# 19  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr10:51448845-125869472
# 20  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr11:69774695-87688378
# 21  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr12:66500000-109373470
# 22  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr14:19050000-107289540
# 23  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr2:162200000-234003741
# 24  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr4:75452279-190000000
# 25  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:48135599-86500000
# 26  ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:87000000-142766515
# 27  ATAC_JV_adipose/samples/AC2/MSC72/problems/chr1:521368-2634220
# 28  ATAC_JV_adipose/samples/AC2/MSC72/problems/chr10:18024675-38818835
# 29  ATAC_JV_adipose/samples/AC2/MSC72/problems/chr10:51448845-125869472
# 30  ATAC_JV_adipose/samples/AC2/MSC72/problems/chr11:69774695-87688378
# ⋮   ⋮
# 225 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr1:521368-2634220
# 226 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr10:18024675-38818835
# 227 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr10:51448845-125869472
# 228 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr11:69774695-87688378
# 229 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr12:66500000-109373470
# 230 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr14:19050000-107289540
# 231 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr2:162200000-234003741
# 232 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr4:75452279-190000000
# 233 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr8:48135599-86500000
# 234 ATAC_JV_adipose/samples/ND2/MSC80/problems/chr8:87000000-142766515
# 235 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr1:521368-2634220
# 236 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr10:18024675-38818835
# 237 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr10:51448845-125869472
# 238 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr11:69774695-87688378
# 239 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr12:66500000-109373470
# 240 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr14:19050000-107289540
# 241 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr2:162200000-234003741
# 242 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr4:75452279-190000000
# 243 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr8:48135599-86500000
# 244 ATAC_JV_adipose/samples/ND2/MSC83/problems/chr8:87000000-142766515
# 245 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr1:521368-2634220
# 246 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr10:18024675-38818835
# 247 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr10:51448845-125869472
# 248 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr11:69774695-87688378
# 249 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr12:66500000-109373470
# 250 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr14:19050000-107289540
# 251 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr2:162200000-234003741
# 252 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr4:75452279-190000000
# 253 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr8:48135599-86500000
# 254 ATAC_JV_adipose/samples/ND2/MSC91/problems/chr8:87000000-142766515
#     pred.in   pred.out
# 1    9.173414        NA
# 2    9.500639        NA
# 3          NA  9.975946
# 4   10.395714        NA
# 5    8.726259        NA
# 6    8.864196        NA
# 7          NA  9.812767
# 8    9.957918        NA
# 9    9.422007        NA
# 10   9.349732        NA
# 11         NA 10.084982
# 12  10.677411        NA
# 13   8.941718        NA
# 14   9.314376        NA
# 15         NA 10.024656
# 16  10.724693        NA
# 17  13.275960        NA
# 18   9.003217        NA
# 19         NA  9.512987
# 20   9.280414        NA
# 21         NA  8.825673
# 22         NA  9.721796
# 23         NA  9.479034
# 24  10.292424        NA
# 25         NA  8.248039
# 26         NA  8.965836
# 27  16.604820        NA
# 28   8.994335        NA
# 29         NA  9.549746
# 30   9.292075        NA
# ⋮   ⋮         ⋮
# 225 16.734111        NA
# 226  8.569650        NA
# 227        NA  9.581733
# 228  8.910037        NA
# 229        NA  8.105919
# 230        NA 10.515632
# 231        NA  9.249824
# 232  9.849232        NA
# 233        NA  7.727264
# 234        NA  8.894274
# 235 16.173925        NA
# 236  8.854291        NA
# 237        NA  9.678172
# 238  9.382827        NA
# 239        NA  8.698131
# 240        NA 10.279521
# 241        NA 10.175694
# 242 10.173320        NA
# 243        NA  7.700199
# 244        NA  8.933774
# 245 16.024628        NA
# 246  8.668856        NA
# 247        NA  9.380476
# 248  8.884180        NA
# 249        NA  7.988283
# 250        NA  9.818526
# 251        NA  9.040388
# 252 10.022462        NA
# 253        NA  7.518335
# 254        NA  8.567189
