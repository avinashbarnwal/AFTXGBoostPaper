# %%
resFileName = "https://raw.githubusercontent.com/tdhock/neuroblastoma-data/master/data/ATAC_JV_adipose/cv/equal_labels/testFolds/1/randomTrainOrderings/1/models/L1reg_linear_all/predictions.csv"

# %%
dataname = 'ATAC_JV_adipose'
filename = paste('https://raw.githubusercontent.com/avinashbarnwal/GSOC-2019/master/AFT/test/data/neuroblastoma-data-master/data/',dataname,'/',sep="")
foldsFileName = paste(filename,'cv/equal_labels/folds.csv',sep="")

# %%
profFile   = read.table(resFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)

# %%
myFile    = read.table(foldsFileName,sep=",",header=T,stringsAsFactors = F,row.names=1)

# %%
myFileTest.id = rownames(subset(myFile,fold==1))

# %%
profTest.id   = rownames(profFile)

# %%
test.id       = data.frame(test.id)

# %%
'ATAC_JV_adipose/samples/AC1/MSC77/problems/chr10:18024675-38818835'
'ATAC_JV_adipose/samples/AC1/MSC77/problems/chr11:69774695-87688378'

# %%
'ATAC_JV_adipose/samples/AC1/MSC77/problems/chr14:19050000-107289540'
'ATAC_JV_adipose/samples/AC1/MSC80/problems/chr14:19050000-107289540'

# %%
sort(myFileTest.id)
# Out:
#   [1] "ATAC_JV_adipose/samples/AC1/MSC77/problems/chr14:19050000-107289540"
#   [2] "ATAC_JV_adipose/samples/AC1/MSC80/problems/chr14:19050000-107289540"
#   [3] "ATAC_JV_adipose/samples/AC1/MSC83/problems/chr14:19050000-107289540"
#   [4] "ATAC_JV_adipose/samples/AC1/MSC91/problems/chr14:19050000-107289540"
#   [5] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr10:51448845-125869472"
#   [6] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr12:66500000-109373470"
#   [7] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr14:19050000-107289540"
#   [8] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr2:162200000-234003741"
#   [9] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:48135599-86500000"
#  [10] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:87000000-142766515"
#  [11] "ATAC_JV_adipose/samples/AC2/MSC72/problems/chr10:51448845-125869472"
#  [12] "ATAC_JV_adipose/samples/AC2/MSC72/problems/chr12:66500000-109373470"
# ...

# %%
test.id1
# Out:
#   [1] "ATAC_JV_adipose/samples/AC1/MSC77/problems/chr14:19050000-107289540"
#   [2] "ATAC_JV_adipose/samples/AC1/MSC80/problems/chr14:19050000-107289540"
#   [3] "ATAC_JV_adipose/samples/AC1/MSC83/problems/chr14:19050000-107289540"
#   [4] "ATAC_JV_adipose/samples/AC1/MSC91/problems/chr14:19050000-107289540"
#   [5] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr10:51448845-125869472"
#   [6] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr12:66500000-109373470"
#   [7] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr14:19050000-107289540"
#   [8] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr2:162200000-234003741"
#   [9] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:48135599-86500000"
#  [10] "ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:87000000-142766515"
#  [11] "ATAC_JV_adipose/samples/AC2/MSC72/problems/chr10:51448845-125869472"
#  [12] "ATAC_JV_adipose/samples/AC2/MSC72/problems/chr12:66500000-109373470"
# ...

# %%
test.id1      = data.frame(test.id1)

# %%
merge(x = test.id , y = test.id1, by = "row.names", all = TRUE)
# Out:
#     Row.names
# 1   1
# 2   10
# 3   100
# 4   101
# 5   102
# 6   103
# 7   104
# 8   105
# 9   106
# 10  107
# 11  108
# 12  109
# 13  11
# 14  110
# 15  111
# 16  112
# 17  113
# 18  114
# 19  115
# 20  116
# 21  117
# 22  118
# 23  119
# 24  12
# 25  120
# 26  121
# 27  122
# 28  123
# 29  124
# 30  125
# ⋮   ⋮
# 101 72
# 102 73
# 103 74
# 104 75
# 105 76
# 106 77
# 107 78
# 108 79
# 109 8
# 110 80
# 111 81
# 112 82
# 113 83
# 114 84
# 115 85
# 116 86
# 117 87
# 118 88
# 119 89
# 120 9
# 121 90
# 122 91
# 123 92
# 124 93
# 125 94
# 126 95
# 127 96
# 128 97
# 129 98
# 130 99
#     test.id
# 1   ATAC_JV_adipose/samples/AC1/MSC77/problems/chr14:19050000-107289540
# 2   ATAC_JV_adipose/samples/AC2/MSC70/problems/chr8:87000000-142766515
# 3   ATAC_JV_adipose/samples/AD2/MSC91/problems/chr2:162200000-234003741
# 4   ATAC_JV_adipose/samples/AD2/MSC91/problems/chr8:48135599-86500000
# 5   ATAC_JV_adipose/samples/AD2/MSC91/problems/chr8:87000000-142766515
# ...
